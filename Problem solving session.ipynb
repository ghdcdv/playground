# %%
"""
Hey Champion! You're tasked with creating a playground simulation program. 
You have to model a playground scenario where kids line up to slide down a slide.

How would you design such a system?
Consider the various elements involved, 
such as representing the playground, 
managing the queue of kids waiting in line, h
andling the slide itself,
and keeping track of which kid completes the slide first. 
Try to outline the classes and methods you would use to build this simulation.


"""

import time
class Queue:
    def __init__(self):
        self.items = []
    def enqueue(self, item):
        self.items.insert(0, item)
    def dequeue(self):
        if self.is_empty():
            return self.items.pop()
        else:
            return None
    def is_empty(self):
        return len(self.items) == 0

class Stack:
    def _init__(self):
        self.items = []
    def push(self,item):
        self.items.append(item)
    def pop(self):
        if not self.is_empty():
            return self.items.pop()
        else:
            return None
class node:
    def __init__(self):
        self.data == data
        self.head == None
class linklisted:
    def __init__(self):
        self.head = None
    def append(self, data):
        new_node = node(data)
        if not self.head:
            self.head = new_node
        else:
            current = seflf.head
            while current.next:
                current = current.next
            current.next = new_node
    def __iter__(self):
        current = self.head
        while current:
            yield current.data
            current = current.next
class kid:
    def __init__(self, name):
        self.name = name

class playground:
    def __init__(self):
        self.line = Queue()
        self.slide = Stack()
        self.completed_slides = linklisted()

    def add_kid_to_line(self, kid):
        self.line.enqueue(kid)
    def send_kid_down_slide(self):
        return self.line.dequeue()
    def complete_slide(self):
        return self.slide.pop()
    def show_playground_state(self):
        print("\nLine", ", ".join(kid.name for kid in self.line.items))
        completed_slide_names = [kid.name for kid in self.completed_slides]
        print("\nCompleted slides", ", ".join(completed_slide_names))
Playground = playground()
kids = [kid("Alice"), id("Maxim"), kid("Aryan"), kid("Ayan"), kid("Kira")]
for kid in kids:
    Playground.add_kid_to_line(kid)

while not Playground.line.is_empty():
    sliding_kid = Playground.send_kid_down_slide()
    if sliding_kid:
        print("\n",sliding_kid.name,"is sliding down the slide...")
        time.sleep(2)
        Playground.slide.push(sliding_kid)
        completed_kid = Playground.complete_slide()
        if completed_kid:
            print(completed_kid.name, "completed the slide!")
            Playground.completed_slides.append(completed_kid)
        Playground.show_playground_state()
    else:
        print("slide is empty")
        break
print("\nAll the kids have completed sliding down tthe slides! Playground is empty.")
# Out:
# slide is empty
#
# All the kids have completed sliding down tthe slides! Playground is empty.
